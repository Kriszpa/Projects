# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("FinalDB.db")
cur = con.cursor()
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///FinalDB.db
# Out:
# 'Connected: @FinalDB.db'

# %%
import pandas
df = pandas.read_csv('https://data.cityofchicago.org/resource/kn9c-c2s2.csv')
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")

# %%
# %sql SELECT * FROM CENSUS_DATA limit 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)]

# %%
df = pandas.read_csv('https://data.cityofchicago.org/resource/9xs2-f89t.csv')
df.to_sql("CHICAGO_PUBLIC_SCHOOLS", con, if_exists='replace', index=False,method="multi")

# %%
# %sql SELECT * FROM CHICAGO_PUBLIC_SCHOOLS limit 2;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl ', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Strong', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', 96.0, 2.0, 96.4, 95.8, '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 150000000000000, 1171699.4579999999, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
df = pandas.read_csv('https://data.cityofchicago.org/resource/ijzp-q8t2.csv')
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False,method="multi")

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA limit 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(13362007, 'JH144408', '2024-02-08T00:00:00.000', '042XX N PULASKI RD', '0910', 'MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'STREET', 0, 0, 1722, 17, 39, 16, '07', 1148966.0, 1927873.0, 2024, '2024-02-15T15:40:52.000', 41.958016245, -87.727741745, '\n,  \n(41.958016245, -87.727741745)'),
#  (13364598, 'JH147461', '2024-02-08T00:00:00.000', '058XX S CALUMET AVE', '0486', 'BATTERY', 'DOMESTIC BATTERY SIMPLE', 'APARTMENT', 0, 1, 232, 2, 20, 40, '08B', 1179481.0, 1866331.0, 2024, '2024-02-15T15:40:52.000', 41.788495114, -87.617445696, '\n,  \n(41.788495114, -87.617445696)'),
#  (13362183, 'JH144519', '2024-02-08T00:00:00.000', '022XX W FARWELL AVE', '1320', 'CRIMINAL DAMAGE', 'TO VEHICLE', 'OTHER (SPECIFY)', 0, 0, 2411, 24, 40, 2, '14', 1159936.0, 1945555.0, 2024, '2024-02-15T15:40:52.000', 42.006316581, -87.68692147600001, '\n,  \n(42.006316581, -87.686921476)'),
# ...

# %%
# %sql SELECT COUNT(arrest) FROM CHICAGO_CRIME_DATA
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(1000,)]

# %%
# %sql SELECT community_area_name and community_area_number from CHICAGO_CRIME_DATA where per_capita_income_<11000
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: community_area_name
# [SQL: SELECT community_area_name and community_area_number from CHICAGO_CRIME_DATA where per_capita_income<11000]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql SELECT ca, community_area_name FROM CENSUS_DATA WHERE per_capita_income_<11000
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(26.0, 'West Garfield Park'),
#  (30.0, 'South Lawndale'),
#  (37.0, 'Fuller Park'),
#  (54.0, 'Riverdale')]

# %%
# %sql SELECT case_number from CHICAGO_CRIME_DATA where primary_type='OFFENSE INVOLVING CHILDREN'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('JH144237',),
#  ('JH145667',),
#  ('JH146117',),
#  ('JH150611',),
#  ('JH145828',),
#  ('JH144058',),
#  ('JH142629',),
#  ('JH144241',)]

# %%
# %sql SELECT Case_Number, Crime_Type, Victim_Age FROM CHICAGO_CRIME_DATA WHERE Crime_Type = 'Kidnapping' AND Victim_Age < 18;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: Crime_Type
# [SQL: SELECT Case_Number, Crime_Type, Victim_Age FROM CHICAGO_CRIME_DATA WHERE Crime_Type = 'Kidnapping' AND Victim_Age < 18;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql SELECT id, case_number, primary_type from chicago_crime_data where location_description='SCHOOL - PUBLIC GROUNDS'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(13362614, 'JH145192', 'THEFT'),
#  (13361558, 'JH144042', 'BATTERY'),
#  (13362296, 'JH144564', 'OTHER OFFENSE'),
#  (13361577, 'JH143941', 'WEAPONS VIOLATION'),
#  (13361789, 'JH143992', 'ASSAULT'),
#  (13362415, 'JH144828', 'ASSAULT'),
#  (13361429, 'JH143845', 'ASSAULT'),
#  (13362749, 'JH145300', 'CRIMINAL DAMAGE'),
#  (13367648, 'JH151052', 'THEFT'),
#  (13361491, 'JH143906', 'ASSAULT'),
#  (13361281, 'JH143574', 'BATTERY'),
#  (13367619, 'JH151188', 'BATTERY'),
#  (13361517, 'JH143785', 'BATTERY'),
#  (13363272, 'JH145943', 'ASSAULT'),
#  (13361263, 'JH143522', 'MOTOR VEHICLE THEFT'),
#  (13360548, 'JH142796', 'ROBBERY'),
#  (13360503, 'JH142774', 'THEFT'),
#  (13361192, 'JH143355', 'ASSAULT'),
#  (13361178, 'JH143236', 'BATTERY'),
#  (13360343, 'JH142476', 'BATTERY'),
#  (13361186, 'JH143191', 'BATTERY')]

# %%
# %sql SELECT name_of_school, elementary_or_high_school, safety_score FROM CHICAGO_PUBLIC_SCHOOLS order by safety_score
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Ariel Elementary Community Academy', 'ES', None),
#  ('Arthur R Ashe Elementary School', 'ES', None),
#  ('Barbara Vick Early Childhood & Family Center', 'ES', None),
#  ('Blair Early Childhood Center', 'ES', None),
#  ('Cyrus H McCormick Elementary School', 'ES', None),
#  ('Daniel C Beard Elementary School', 'ES', None),
#  ('DeVry University Advantage Academy High School', 'HS', None),
#  ('Disney II Magnet School', 'ES', None),
#  ('Dr Jorge Prieto Math and Science', 'ES', None),
#  ('Dr  Martin Luther King  Jr  College Prep High School', 'HS', None),
#  ('Edward Everett Elementary School', 'ES', None),
#  ('Enrico Tonti Elementary School', 'ES', None),
#  ('Franz Peter Schubert Elementary School', 'ES', None),
#  ('Frederick Stock Elementary School', 'ES', None),
#  ('George Leland Elementary School', 'ES', None),
#  ('Henry D Lloyd Elementary School', 'ES', None),
#  ('High School of Leadership at South Shore', 'HS', None),
# ...

# %%
# %sql SELECT community_area_name from CENSUS_DATA where percent_households_below_poverty=MAX
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: MAX
# [SQL: SELECT community_area_name from CENSUS_DATA where percent_households_below_poverty=MAX]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql SELECT community_area_name from CENSUS_DATA Order by percent_households_below_poverty LIMIT 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Edison Park',),
#  ('Mount Greenwood',),
#  ('Beverly',),
#  ('Norwood Park',),
#  ('North Center',)]

# %%
# %sql select community_area from chicago_crime_data group by community_area order by count(*) desc limit 1
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25,)]

# %%
# %sql select community_area_name from census_data where ca=25
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = "KIDNAPPING" AND DESCRIPTION LIKE “%CHILD%”
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: “
# [SQL: SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = "KIDNAPPING" AND DESCRIPTION LIKE “%CHILD%”]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE HARDSHIP_INDEX IN (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]
